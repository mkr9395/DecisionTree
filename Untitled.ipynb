# %% [markdown]
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
msft = yf.Ticker("MSFT")

# %%
msft_news = msft.get_news()
msft_news
# Out:
# [{'uuid': '08561c49-1aed-38af-b580-d344931bf917',
#   'title': 'Is Roblox Stock A Buy Right Now After Q2 Earnings Results?',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/08561c49-1aed-38af-b580-d344931bf917/is-roblox-stock-a-buy-right.html',
#   'providerPublishTime': 1661278968,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Kn2Npct2QvkS3qVvr.Icuw--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/uu/api/res/1.2/mIkioCQBGUpTHNbuL1kVMQ--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/9b9cddc8d7aaa24c3da2a886ecd97577',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
# ...

# %%
msft_news_df = pd.DataFrame(msft_news)
msft_news_df
# Out:
#                                    uuid  \
# 0  08561c49-1aed-38af-b580-d344931bf917
# 1  064bb010-1121-31bc-a1b8-20494e5a4988
# 2  c02916bd-2edf-3d7d-867d-01ae52c7a7fb
# 3  f30a17cb-310c-3c55-8460-d051cf23e687
# 4  dba9b7b0-20f3-3f0f-b2b4-8d4b45a7455d
# 5  f47005aa-26c1-38d3-9e09-5d3184fc7adb
# 6  e3a13472-49d3-329f-8974-5b8d9219151e
# 7  60c00701-2b3a-306e-927c-1ce51cb9d8e2
#
#                                                title  \
# 0  Is Roblox Stock A Buy Right Now After Q2 Earni...
# 1  Zoom’s Enterprise Bet Is Delayed as Company Cu...
# 2  Oracle (ORCL) Hit by Lawsuit in the U.S. for V...
# 3  Is Most-Watched Stock Microsoft Corporation (M...
# 4  Qatar Wealth Fund Invests in Celonis at $13 Bi...
# 5  3 Surefire Investments You'll Thank Yourself F...
# 6  Podcast: Meredith Leapley on Microsoft acceler...
# 7  Big Tech Is Under Pressure To Turn Its Back On...
#
#                          publisher  \
# 0        Investor's Business Daily
# 1                        Bloomberg
# ...

# %%
msft_news.loc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MOHIT~1.KUM\AppData\Local\Temp/ipykernel_26032/4212576360.py in <module>
# ----> 1 msft_news.loc[0]['title']
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
baly = yf.Ticker("BALY")

# %%
baly.ticker
# Out:
# 'BALY'

# %%
baly_news = baly.get_news()

# %%
baly_news_df = pd.DataFrame(baly_news)
baly_news_df
# Out:
#                                    uuid  \
# 0  26f65b11-5401-36f0-a823-2c2a50450224
# 1  51f4530d-a856-3da3-9145-e6042caf7161
# 2  02528e67-2371-317a-baf2-19bee8def5e3
# 3  ce97b708-6283-3b04-b1c3-8b4e334d4c20
# 4  e6a1f304-d5ba-3ea4-9cbd-8c0fb9407f3a
# 5  bb3e6700-e09d-3361-b3b9-062c7efcc554
# 6  e4158235-be94-389d-ac15-82dc39b2e63f
# 7  b2b05a6b-1059-38e9-96f0-8f5f4083f17d
#
#                                                title  \
# 0  Bally's Corporation Announces Second Quarter 2...
# 1  Bally's inks sports betting deal with New York...
# 2  Bally's Becomes An Official Sports Betting Par...
# 3  Analysts Estimate Bally's Corporation (BALY) t...
# 4    Bally's Announces Final Results of Tender Offer
# 5  Bally's Announces Preliminary Results of Tende...
# 6  Bally’s and Verra Mobility Stock See Action Fr...
# 7  Bally's To Report Second Quarter 2022 Results ...
#
#                          publisher  \
# 0                      PR Newswire
# 1  American City Business Journals
# ...

# %%
baly_news_df[['title','providerPublishTime']]
# Out:
#                                                title  providerPublishTime
# 0  Bally's Corporation Announces Second Quarter 2...           1659610800
# 1  Bally's inks sports betting deal with New York...           1659369056
# 2  Bally's Becomes An Official Sports Betting Par...           1659353400
# 3  Analysts Estimate Bally's Corporation (BALY) t...           1659016922
# 4    Bally's Announces Final Results of Tender Offer           1658921400
# 5  Bally's Announces Preliminary Results of Tende...           1658748600
# 6  Bally’s and Verra Mobility Stock See Action Fr...           1658523600
# 7  Bally's To Report Second Quarter 2022 Results ...           1658348100

# %%
baly_news_df['title']
# Out:
# 0    Bally's Corporation Announces Second Quarter 2...
# 1    Bally's inks sports betting deal with New York...
# 2    Bally's Becomes An Official Sports Betting Par...
# 3    Analysts Estimate Bally's Corporation (BALY) t...
# 4      Bally's Announces Final Results of Tender Offer
# 5    Bally's Announces Preliminary Results of Tende...
# 6    Bally’s and Verra Mobility Stock See Action Fr...
# 7    Bally's To Report Second Quarter 2022 Results ...
# Name: title, dtype: object
